# %% [markdown]
# # programming language
#
# #### A programming language is a vocabulary and set of grammatical rules for instructing a computer or computing device to perform a specific task.
# #### Each programming language has a unique set of keywords (a word that it understands) and special syntax for organizing program instruction.
# #### A programming language is also known as a computer language computer system or programming system.

# %% [markdown]
# # python
#
# #### python is a General purpose, High Level Object Oriented, Interpreated interactive, Scripting and Dynamically typed language.
# #### Python is design for highly readable.
# #### Its flexibility allows it to do many things both big and small.
# #### Python can be used to write small programs but as well as complex large scale enterprise solution

# %% [markdown]
# ## General purpose
#
# #### python is not specific for any area happily we can use any type of applications like system alone application, web-based application, data science application, machine learning application etc.

# %% [markdown]
# # High level
#
#
# #### programmer friendly not machine friendly, Low-Level things are take care by language itself like memory management, security, object deleting etc

# %% [markdown]
# # History of python
#
# #### python was developed by GUIDO VAN ROSSUM in 1989 while working in NATIONAL RESEARCH INSTITUTE IN NETHERLANDS.
# ####  Officially 20feb 1991 python was released in the market for public
# ##### Python is derived form many other languages including ABC, MODULA-3, ALGO-68, C, C++, SMALL TALK, UNIX SHELL and many other shells scripting
# #### Python borrowed functional programming concept form language C.
# #### Python borrowed OOPS (OBJECT ORIENTED) programming concept form language C++.
# #### Python borrowed scripting programming concept form PERL and SHELL SCRIPTING.
# #### Python borrowed modular programming concept form MODULA-3.
# #### MOST OF THE SYNTAX OF THE PYTHON is derived from ABC and C language

# %% [markdown]
# # Why the name PYTHON
# #### Python named after the British comedy group MONTY PYTHON he was found of watching the comedy series THE MONTY PYTHON FLING CIRCUS.
# #### This comedy series is broadcasted by BBC in 1969 to 1974

# %% [markdown]
# # Features of Python
# ## 1 Simple and Easy to Use
# #### python is a simplest programming language in all languages,
# #### its syntax is very much familiar with English language,
# #### python code is very concise code (less line of code)
# #### less amount of reserved word available in python
#
# ## 2.	Freeware and Open source
# #### To use python, we don’t have to pay any amount of money
# #### The source code of python is available for any one,
# #### The customization of python is possible because it is open source, for that reason many-version of python is available in the market.
# ## Falvor of python
# #### ince python is opensource language so developer do modification according their uses for that reason many flavours of python come into the pictures.
# #### To ork with java language JYTHON is available
# #### To ork with .net language IRON-PYTHON is available
# #### To wok with data ANACONDA is availble
#
# ## 3High level programming language
# #### python is programmer friendly language not machine friendly language.
# #### A programmer can easily write program they don’t have worry about low level activities, internally python virtual machine is taking care all the activities
#
# ## 4.	platform independent
#
# #### write python code once and run anywhere
# #### python virtual machine is responsible to execute code in any platform.
# ####  python virtual machine is platform dependent
# ![Screenshot%202023-04-12%20045908.png](attachment:Screenshot%202023-04-12%20045908.png)
#
# ## 5.	Portable
#
# #### 	The process of migrating python application is one platform to another platform is call portability.
# ## 6	Dynamically typed
# •
# ## 7.	Both procedure oriented or object oriented
# ## 8.	Interpreted
# ## 9.	Extensible.
# #### •	We can use other programming language code in our python code.
# #### •	 Overall performance is improved
# ## 10.	Embedded
# #### •	We can use python code in any other lanuage.
#
# ## Python versions
# #### •	In python the two versions are available 2x and 3x.
# #### •	3x is not a extended version of python,
# #### •	python 3x is developed by scratch.
# #### •	Backward compatibility is not supported in python 3x version.

# %%
# Out:
#   File "C:\Users\satee\AppData\Local\Temp\ipykernel_11308\3531140543.py", line 1
#     print(open("sql notes.docx")).read())
#                                         ^
# SyntaxError: unmatched ')'
