# %% [markdown]
# # How to approach the problem
# #### •	We learn programming language to solve the problem which we face in our day-to-day life or any problem which we are facing in our life, hence in programming we have a best way to approach the problem
#
# ## 1.	Analyse the problem
# ## 2.	Think of the solution
# ## 3.	write down the solution
# ## 4.	Code the solution
#
# #### •	To write down any solution in programming we have a very unique and simple way and it is known as FLOW CHART FLOW        CHART
# #### •	It is a diagrammatic representation to a given problem
# #### •	It helps us to break down any process into a smaller step we can understand easily.
# #### •	 It is language independent
# #### •	It is very good documentation of any problem
#
#
# # Component of Flow chart
# ![Screenshot%202023-04-13%20041923.png](attachment:Screenshot%202023-04-13%20041923.png)

# %% [markdown]
# ## practice  for Flow chart
